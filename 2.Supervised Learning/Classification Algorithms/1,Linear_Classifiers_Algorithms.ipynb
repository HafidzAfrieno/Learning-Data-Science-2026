# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
df = pd.read_csv('../../0.dataset/dataset_serangan_jantung_clean.csv')
df.head()
# Out:
#        Usia  Jenis_Kelamin  Tipe_Nyeri_Dada  Tekanan_Darah_Rest  Kolesterol  \
# 0  0.814243              1                2            1.448084   -1.334858
# 1  1.677071              0                3           -0.951547   -1.468588
# 2  0.150530              1                0            0.659164    0.537365
# 3 -0.778668              1                1            0.790651   -0.917935
# 4  1.079729              1                0            1.711058   -1.397790
#
#    Gula_Darah_Puasa  EKG_Rest  Detak_Jantung_Max  Angina_Olahraga  Oldpeak_ST  \
# 0                 0         1           0.512778                0   -1.469722
# 1                 0         0           1.065661                0    1.155114
# 2                 0         1           0.907694                0    1.210962
# 3                 0         1           1.091989                1    1.155114
# 4                 0         1          -0.171745                1    1.043419
#
#    Kemiringan_ST  Jumlah_Pembuluh_Darah  Thalassemia       BMI  \
# 0              2                      1            3  0.292643
# 1              0                      0            3  0.467130
# 2              0                      0            2 -0.437034
# 3              1                      0            2  0.816106
# 4              0                      2            3 -0.008746
#
#    Serangan_Jantung
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
df_x = df.drop(columns='Serangan_Jantung')
df_y = df[['Serangan_Jantung']]
