# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../../0.dataset/dataset_serangan_jantung.csv')
df.head()
# Out:
#    Usia  Jenis_Kelamin  Tipe_Nyeri_Dada  ...  Thalassemia   BMI  Serangan_Jantung
# 0    67              1                2  ...            3  31.0                 0
# 1    80              0                3  ...            3  32.1                 1
# 2    57              1                0  ...            2  26.4                 1
# 3    43              1                1  ...            2  34.3                 1
# 4    71              1                0  ...            3  29.1                 1
#
# [5 rows x 15 columns]

# %%
feauter_scaling  = ['Usia','Tekanan_Darah_Rest','Kolesterol','Detak_Jantung_Max','Oldpeak_ST','BMI']
